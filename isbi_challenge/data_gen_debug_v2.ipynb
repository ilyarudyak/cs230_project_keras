# %%
from PIL import Image
import numpy as np
# from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from pathlib import Path
import matplotlib.pyplot as plt

from model.data_gen import ISBI2012

# %load_ext autoreload
# %autoreload 2
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## augmentation

# %% [markdown]
# ### train data - no crop

# %%
original_size, target_size = 512, 512

# %%
data = ISBI2012(target_size=target_size)

# %%
train_gen = data.generator(batch_size=1,  mode='training')

# %%
n = 3
fig, ax = plt.subplots(n, 4, figsize=(15, 15))
[axi.set_xticks([]) for axi in ax.ravel()]
[axi.set_yticks([]) for axi in ax.ravel()]
for i in range(n):
    image_batch, mask_batch = next(train_gen)
    ax[i, 0].imshow(data.image_data[i].reshape(original_size, original_size), cmap='gray')
    ax[i, 1].imshow(image_batch.reshape(target_size, target_size), cmap='gray')
    ax[i, 2].imshow(data.mask_data[i].reshape(original_size, original_size), cmap='gray')
    ax[i, 3].imshow(mask_batch.reshape(target_size, target_size), cmap='gray')
# Out:
# idx=2
# idx=2
# idx=5
# idx=5
# idx=3
# idx=3

# %% [markdown]
# ### train data - crop

# %%
original_size, target_size = 512, 256

# %%
data = ISBI2012(target_size=target_size)

# %%
train_gen = data.generator(batch_size=1,  mode='training')

# %%
n = 3
fig, ax = plt.subplots(n, 4, figsize=(15, 15))
[axi.set_xticks([]) for axi in ax.ravel()]
[axi.set_yticks([]) for axi in ax.ravel()]
for i in range(n):
    image_batch, mask_batch = next(train_gen)
    ax[i, 0].imshow(data.image_data[i].reshape(original_size, original_size), cmap='gray')
    ax[i, 1].imshow(image_batch.reshape(target_size, target_size), cmap='gray')
    ax[i, 2].imshow(data.mask_data[i].reshape(original_size, original_size), cmap='gray')
    ax[i, 3].imshow(mask_batch.reshape(target_size, target_size), cmap='gray')
# Out:
# idx=2
# idx=2
# idx=5
# idx=5
# idx=3
# idx=3

# %% [markdown]
# ### val data

# %%
original_size, target_size = 512, 128

# %%
data = ISBI2012(target_size=target_size)

# %%
val_gen = data.generator(batch_size=1,  mode='validation')

# %%
n, m = 3, 24
fig, ax = plt.subplots(n, 4, figsize=(15, 15))
# [axi.set_xticks([]) for axi in ax.ravel()]
# [axi.set_yticks([]) for axi in ax.ravel()]
for i in range(n):
    image_batch, mask_batch = next(val_gen)
    ax[i, 0].imshow(data.image_data[i+m].reshape(original_size, original_size), cmap='gray')
    ax[i, 1].imshow(image_batch.reshape(target_size, target_size), cmap='gray')
    ax[i, 2].imshow(data.mask_data[i+m].reshape(original_size, original_size), cmap='gray')
    ax[i, 3].imshow(mask_batch.reshape(target_size, target_size), cmap='gray')
