# %%
import utils
from train import Trainer, Tuner
from pathlib import Path
from model.bigger_leaky_unet import BiggerLeakyUnet
from IPython.display import Image
from IPython.core.display import HTML 
import numpy as np

import seaborn as sns
sns.set()

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## transfer learning

# %% [markdown]
# ### (1) UNet with VGG-16 encoder

# %% [markdown]
# It looks like in this case `1e-4` is quite good. We remove bigger rates using results of training on a few epochs.

# %%
dir_path = Path('experiments/transf_learn_vgg_toy')

# %%
histories_vgg_lr_toy = list(dir_path.glob('history_learning_rate*'))

# %%
histories_vgg_lr_toy = sorted(histories_vgg_lr_toy, key=utils.get_param_num, reverse=True)

# %%
histories_vgg_lr_toy
# Out:
# [PosixPath('experiments/transf_learn_vgg_toy/history_learning_rate_0.1.pickle'),
#  PosixPath('experiments/transf_learn_vgg_toy/history_learning_rate_0.01.pickle'),
#  PosixPath('experiments/transf_learn_vgg_toy/history_learning_rate_0.001.pickle'),
#  PosixPath('experiments/transf_learn_vgg_toy/history_learning_rate_0.0001.pickle'),
#  PosixPath('experiments/transf_learn_vgg_toy/history_learning_rate_1e-05.pickle'),
#  PosixPath('experiments/transf_learn_vgg_toy/history_learning_rate_1e-06.pickle')]

# %%
utils.plot_metric_paths('jaccard_coef', histories_vgg_lr_toy[3:], param_name='learning_rate')

# %%
utils.plot_metric_paths('val_jaccard_coef', histories_tf_lr_toy[3:], param_name='learning_rate')

# %% [markdown]
# ### (2) UNet with resnet50 encoder

# %%
dir_path = Path('experiments/transf_learn_resnet_toy')

# %%
histories_resnet_lr_toy = list(dir_path.glob('history_learning_rate*'))

# %%
histories_resnet_lr_toy = sorted(histories_resnet_lr_toy, 
                                 key=utils.get_param_num, reverse=True)

# %%
histories_resnet_lr_toy

# %%
utils.plot_metric_paths('jaccard_coef', histories_resnet_lr_toy, param_name='learning_rate')
