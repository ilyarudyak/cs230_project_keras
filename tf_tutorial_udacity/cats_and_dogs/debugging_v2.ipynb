# %%
import PIL.Image as Image
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

from data_prep import get_generators, get_generators_aug, get_generators_debug
from train import Trainer
import utils

import tensorflow_hub as hub
import tensorflow_datasets as tfds

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # transfer learning

# %% [markdown]
# ## grace_hopper

# %%
trainer = Trainer()
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
IMAGE_RES = trainer.mobile_net.config['IMAGE_RES']

# %%
grace_hopper = tf.keras.utils.get_file('image.jpg','https://storage.googleapis.com/download.tensorflow.org/example_images/grace_hopper.jpg')
grace_hopper = Image.open(grace_hopper).resize((IMAGE_RES, IMAGE_RES))

# %%
plt.imshow(grace_hopper);

# %%
trainer.predict_image(grace_hopper)
# Out:
# 'military uniform'

# %% [markdown]
# ## cats and dogs

# %% [markdown]
# So here we have some more crazy code from `tf` to load full `cats and dogs` dataset.
